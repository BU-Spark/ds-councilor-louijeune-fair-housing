# %%
# made by sophie
import pandas as pd

df =pd.read_csv('income-restricted-inventory-2021.csv')
section_8 = df[df['Section 8'] == 'Y']
neighborhood_counts = section_8.groupby('Neighborhood')['Section 8'].count().sort_values(ascending=False)
print(neighborhood_counts)
# Out:
# Neighborhood
# Roxbury          54
# Dorchester       40
# South End        22
# Jamaica Plain    14
# Fenway           11
# Brighton          8
# Chinatown         8
# East Boston       7
# Charlestown       5
# Mission Hill      5
# Roslindale        5
# Downtown          4
# Beacon Hill       4
# Allston           4
# South Boston      3
# Mattapan          3
# West End          2
# Hyde Park         2
# North End         2
# Back Bay          2
# West Roxbury      1
# Name: Section 8, dtype: int64

# %%
# Out:
# Neighborhood
# Roxbury          10850
# Dorchester        8607
# South End         5408
# Jamaica Plain     4001
# Brighton          3412
# South Boston      3389
# East Boston       2761
# Mission Hill      2591
# Charlestown       2405
# Fenway            2252
# Name: Total Income-Restricted, dtype: int64
