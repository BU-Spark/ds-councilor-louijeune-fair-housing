# %%
# made by sophie
import folium
import pandas as pd

zipcodes = pd.read_csv('boston_zips.csv')

map_boston = folium.Map(location=[42.361145, -71.057083], zoom_start=13)

folium.Marker(
    location=[42.2996, -71.0649],
    icon=folium.Icon(color="black") #Dorchester
).add_to(map_boston)

folium.Marker(
    location=[42.3489, -71.1605], icon=folium.Icon(color="red") #Brighton
).add_to(map_boston)

folium.Marker(
    location=[42.3132, -71.1141], icon=folium.Icon(color="purple") #Jamaica Plain
).add_to(map_boston)

folium.Marker(
    location=[42.3407, -71.0706], icon=folium.Icon(color="orange") #South End
).add_to(map_boston)

folium.Marker(
    location=[42.3126, -71.0899], icon=folium.Icon(color="blue") #Roxbury
).add_to(map_boston) 

map_boston
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
import pandas as pd
#Zip codes with the least affordable housing to contrast where the highest areas are
zipcodes = pd.read_csv('boston_zips.csv')

map_boston = folium.Map(location=[42.361145, -71.057083], zoom_start=13)

folium.Marker(
    location=[42.3463, -71.0421],
    icon=folium.Icon(color="black") #South Boston Waterfront
).add_to(map_boston)

folium.Marker(
    location=[42.3407, -71.0706],
    icon=folium.Icon(color="red") #South End
).add_to(map_boston)

folium.Marker(
    location=[42.3652, -71.0641], icon=folium.Icon(color="purple") #West End
).add_to(map_boston)

folium.Marker(
    location=[42.3467, -71.0972], icon=folium.Icon(color="orange") #Fenway
).add_to(map_boston)

folium.Marker(
    location=[42.3489, -71.1605], icon=folium.Icon(color="blue") #Brighton
).add_to(map_boston) 

map_boston
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
